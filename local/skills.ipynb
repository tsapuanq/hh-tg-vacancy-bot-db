# %%
import pandas as pd

# %%
df = pd.read_csv('vacancies_with_roles.csv')
df.head()
# Out:
#      id                                            title  \
# 0  1483                           Senior DevOps Engineer
# 1    21  Бизнес/Системный аналитик (Full Stack Analityc)
# 2    59    Senior risk modeling analyst (скоринг модели)
# 3    69                     Системный аналитик (Middle+)
# 4  1008                                 DataOps Engineer
#
#                                          description  is_relevant  \
# 0  Netcracker’s Project Enablement Team is a glob...         True
# 1  Обязанности:\n\nАнализировать требования к сис...         True
# 2  Компания KMF – лидер на рынке микрофинансирова...         True
# 3  Мы - молодая быстрорастущая IТ-компания, спосо...         True
# 4  The IT company Andersen invites an experienced...         True
#
#                                       summary_duties  \
# 0  Automate deployment, configuration of infrastr...
# 1  Анализ требований к системам, их производитель...
# 2  Разработка скоринговых моделей\nПоддержка сист...
# 3  Сбор, анализ и детализация требований.\nПодгот...
# 4  Migrating legacy data pipelines to a modern La...
#
#                                 summary_requirements  \
# 0  1+ years of relevant work experience as a DevO...
# 1  Опыт работы в области бизнес/системного анализ...
# 2  Высшее техническое/математическое/IT/финансы/э...
# 3  Опыт работы системным аналитиком от 3-х лет.\n...
# 4  Bachelor's or Master's degree in Computer Scie...
#
#                                      summary_company  \
# 0  Netcracker's Project Enablement Team aims to p...
# 1                                         Не указано
# 2  KMF – лидер на рынке микрофинансирования, откр...
# 3  Молодая быстрорастущая IТ-компания, способству...
# 4  The IT company Andersen invites an experienced...
#
#                                url published_at                processed_at  \
# 0  https://hh.kz/vacancy/120826624   2025-05-21  2025-05-21 16:46:13.858273
# 1  https://hh.kz/vacancy/120662304   2025-05-18  2025-05-19 07:03:57.418759
# 2  https://hh.kz/vacancy/120670021   2025-05-19  2025-05-19 07:03:57.418759
# 3  https://hh.kz/vacancy/120415363   2025-05-18  2025-05-19 07:03:57.418759
# 4  https://hh.kz/vacancy/120757349   2025-05-20  2025-05-20 16:42:10.836691
#
#    ...                                             skills published_date  \
# 0  ...  Linux, AWS, Terraform, DevOps, Python, OpenShi...    21 мая 2025
# 1  ...  Системное мышление, Умение анализировать, Рабо...    18 мая 2025
# 2  ...  Python, SQL, Английский язык, Математический а...    19 мая 2025
# 3  ...                                         Не указано    18 мая 2025
# 4  ...  DataOps, Apache Spark, Kubernetes, Trino, Pres...    20 мая 2025
#
#                         work_format working_hours  \
# 0                            Гибрид             8
# 1  На месте работодателя или гибрид             8
# 2                        Не указано             8
# 3             На месте работодателя             8
# 4                        Не указано             8
#
#                                              company  \
# 0                 ТОО Неткрэкер Текнолоджи Казахстан
# 1                                ТОО Inter Solutions
# 2            АО Микрофинансовая организация KMF(КМФ)
# 3  Частная компания “Automated Communication Solu...
# 4                                           Andersen
#
#                                         salary experience  \
# 0                                   Не указано    3–6 лет
# 1  от 800 000 до 1 100 000 ₸ за месяц, на руки    3–6 лет
# 2                                   Не указано    3–6 лет
# 3                                   Не указано    3–6 лет
# 4                                   Не указано    3–6 лет
#
#                                    employment_type schedule  canonical_role
# 0                                 Полная занятость      5/2          DevOps
# 1  Полная занятость\nВозможно временное оформление      5/2  System Analyst
# 2                                 Полная занятость      5/2    Data Analyst
# 3                                 Полная занятость      5/2  System Analyst
# 4                                 Полная занятость      5/2   Data Engineer
#
# [5 rows x 23 columns]

# %%
df['skills'].to_csv('skills.csv', index=False)

# %%
pd.DataFrame(df['skills'].unique(), columns=['skill']).to_csv('unique_skills.csv', index=False)

# %%
df
# Out:
#         id                                            title  \
# 0     1483                           Senior DevOps Engineer
# 1       21  Бизнес/Системный аналитик (Full Stack Analityc)
# 2       59    Senior risk modeling analyst (скоринг модели)
# 3       69                     Системный аналитик (Middle+)
# 4     1008                                 DataOps Engineer
# ..     ...                                              ...
# 735  24635                                      ETL-инженер
# 736  24652                                  Аналитик данных
# 737  24747              Системный аналитик / System Analyst
# 738  23633                               Системный аналитик
# 739  24040                                  Аналитик данных
#
#                                            description  is_relevant  \
# 0    Netcracker’s Project Enablement Team is a glob...         True
# 1    Обязанности:\n\nАнализировать требования к сис...         True
# 2    Компания KMF – лидер на рынке микрофинансирова...         True
# 3    Мы - молодая быстрорастущая IТ-компания, спосо...         True
# 4    The IT company Andersen invites an experienced...         True
# ..                                                 ...          ...
# 735  Ищем ETL-инженера, который будет заниматься за...         True
# 736  Требования:\n\nВысшее образование (экономика, ...         True
# 737  О компании:\n\nКомпания Hardcode является пост...         True
# 738  Cyber Staff — амбициозное IT агентство, основа...         True
# 739  Обязанности:\nВзаимодействие с бизнес-заказчик...         True
#
#                                         summary_duties  \
# 0    Automate deployment, configuration of infrastr...
# 1    Анализ требований к системам, их производитель...
# 2    Разработка скоринговых моделей\nПоддержка сист...
# 3    Сбор, анализ и детализация требований.\nПодгот...
# 4    Migrating legacy data pipelines to a modern La...
# ..                                                 ...
# 735  Разработка и поддержка ETL-процессов для интег...
# 736  Анализ, обработка, интерпретация данных.\nПост...
# 737  Выявление потребностей заказчика и бизнес-поль...
# 738                                         Не указано
# 739                                         Не указано
#
#                                   summary_requirements  \
# 0    1+ years of relevant work experience as a DevO...
# 1    Опыт работы в области бизнес/системного анализ...
# 2    Высшее техническое/математическое/IT/финансы/э...
# 3    Опыт работы системным аналитиком от 3-х лет.\n...
# 4    Bachelor's or Master's degree in Computer Scie...
# ..                                                 ...
# 735  2+ года опыта c ETL / аналитики данных\nОтличн...
# 736  Высшее образование (экономика, аналитика, смеж...
# 737  Системное аналитическое мышление\nУмение управ...
# 738                                         Не указано
# 739                                         Не указано
#
#                                        summary_company  \
# 0    Netcracker's Project Enablement Team aims to p...
# 1                                           Не указано
# 2    KMF – лидер на рынке микрофинансирования, откр...
# 3    Молодая быстрорастущая IТ-компания, способству...
# 4    The IT company Andersen invites an experienced...
# ..                                                 ...
# 735  Компания занимается загрузкой и интеграцией да...
# 736                                         Не указано
# 737  Hardcode - поставщик услуг по разработке прогр...
# 738                                         Не указано
# 739                                         Не указано
#
#                                  url published_at                processed_at  \
# 0    https://hh.kz/vacancy/120826624   2025-05-21  2025-05-21 16:46:13.858273
# 1    https://hh.kz/vacancy/120662304   2025-05-18  2025-05-19 07:03:57.418759
# 2    https://hh.kz/vacancy/120670021   2025-05-19  2025-05-19 07:03:57.418759
# 3    https://hh.kz/vacancy/120415363   2025-05-18  2025-05-19 07:03:57.418759
# 4    https://hh.kz/vacancy/120757349   2025-05-20  2025-05-20 16:42:10.836691
# ..                               ...          ...                         ...
# 735  https://hh.kz/vacancy/123872415   2025-08-11  2025-08-11 08:36:40.085627
# 736  https://hh.kz/vacancy/123875895   2025-08-11  2025-08-11 08:36:40.085627
# 737  https://hh.kz/vacancy/123869756   2025-08-11  2025-08-11 08:36:40.085627
# 738  https://hh.kz/vacancy/123697561   2025-08-06  2025-08-06 14:43:06.990200
# 739  https://hh.kz/vacancy/123744561   2025-08-07  2025-08-07 14:44:42.923216
#
#      ...                                             skills   published_date  \
# 0    ...  Linux, AWS, Terraform, DevOps, Python, OpenShi...      21 мая 2025
# 1    ...  Системное мышление, Умение анализировать, Рабо...      18 мая 2025
# 2    ...  Python, SQL, Английский язык, Математический а...      19 мая 2025
# 3    ...                                         Не указано      18 мая 2025
# 4    ...  DataOps, Apache Spark, Kubernetes, Trino, Pres...      20 мая 2025
# ..   ...                                                ...              ...
# 735  ...                                         Не указано  11 августа 2025
# 736  ...                                         Не указано  11 августа 2025
# 737  ...  Разработка технических заданий, Системный анал...  11 августа 2025
# 738  ...                  SQL, Системный анализ, REST, SOAP   6 августа 2025
# 739  ...                                         Не указано   7 августа 2025
#
#                           work_format working_hours  \
# 0                              Гибрид             8
# 1    На месте работодателя или гибрид             8
# 2                          Не указано             8
# 3               На месте работодателя             8
# 4                          Не указано             8
# ..                                ...           ...
# 735             На месте работодателя             8
# 736             На месте работодателя             8
# 737             На месте работодателя             8
# 738                          Удалённо             8
# 739             На месте работодателя             8
#
#                                                company  \
# 0                   ТОО Неткрэкер Текнолоджи Казахстан
# 1                                  ТОО Inter Solutions
# 2              АО Микрофинансовая организация KMF(КМФ)
# 3    Частная компания “Automated Communication Solu...
# 4                                             Andersen
# ..                                                 ...
# 735    Публичная Компания «Freedom Finance Global PLC»
# 736                              ТОО Людмила-KZ TM Аян
# 737                                      ТОО Hard Code
# 738                                   ИП AWESOME STAFF
# 739                       АО «Freedom Bank Kazakhstan»
#
#                                           salary experience  \
# 0                                     Не указано    3–6 лет
# 1    от 800 000 до 1 100 000 ₸ за месяц, на руки    3–6 лет
# 2                                     Не указано    3–6 лет
# 3                                     Не указано    3–6 лет
# 4                                     Не указано    3–6 лет
# ..                                           ...        ...
# 735                                   Не указано    3–6 лет
# 736                                   Не указано   1–3 года
# 737               от 400 000 ₸ за месяц, на руки    3–6 лет
# 738                                   Не указано    3–6 лет
# 739                                   Не указано    3–6 лет
#
#                                      employment_type schedule  canonical_role
# 0                                   Полная занятость      5/2          DevOps
# 1    Полная занятость\nВозможно временное оформление      5/2  System Analyst
# 2                                   Полная занятость      5/2    Data Analyst
# 3                                   Полная занятость      5/2  System Analyst
# 4                                   Полная занятость      5/2   Data Engineer
# ..                                               ...      ...             ...
# 735                                 Полная занятость      5/2   Data Engineer
# 736                                 Полная занятость      5/2    Data Analyst
# 737                                 Полная занятость      5/2  System Analyst
# 738                                 Полная занятость      5/2  System Analyst
# 739                                 Полная занятость      5/2    Data Analyst
#
# [740 rows x 23 columns]

# %%
import re
import pandas as pd
from datetime import date, timedelta

# =========================
# Синонимы / нормализация
# =========================
SKILL_SYNONYMS = {
    # облака
    "amazon web services": "aws", "aws": "aws",
    "microsoft azure": "azure", "azure": "azure",
    "google cloud": "gcp", "gcp": "gcp", "google cloud platform": "gcp",

    # BI / аналитика
    "power bi": "powerbi", "ms power bi": "powerbi", "microsoft power bi": "powerbi",
    "powerbi": "powerbi", "power-bi": "powerbi", "power bi,": "powerbi",
    "qlik sense": "qlik", "qlikview": "qlik", "qlick": "qlik", "qlik": "qlik",
    "looker studio": "looker", "google data studio": "looker", "looker": "looker",
    "metabase": "metabase", "apache superset": "superset", "superset": "superset",
    "tableau": "tableau",
    "power query": "powerquery", "powerquery": "powerquery", "dax": "dax",

    # офис/таблицы
    "ms excel": "excel", "microsoft excel": "excel", "excel": "excel",

    # базы/платформы/оркестрация/хранилища
    # ВАЖНО: не трогаем здесь SQL-варианты — схлопываем ниже через регексы
    "clickhouse": "clickhouse", "greenplum": "greenplum",
    "snowflake": "snowflake", "redshift": "redshift", "bigquery": "bigquery",
    "data warehouse": "dwh", "dwh": "dwh", "кхд": "dwh",
    "dbt": "dbt",
    "apache airflow": "airflow", "airflow": "airflow",
    "spark": "spark", "apache spark": "spark", "pyspark": "pyspark",
    "apache kafka": "kafka", "kafka": "kafka",
    "apache nifi": "nifi", "nifi": "nifi",

    # devops / платформа
    "docker": "docker",
    "kubernetes": "kubernetes", "k8s": "kubernetes",
    "helm": "helm", "terraform": "terraform", "ansible": "ansible",
    "jenkins": "jenkins", "zabbix": "zabbix",
    "gitlab ci": "gitlabci", "gitlab-ci": "gitlabci", "gitlabci": "gitlabci",
    "ci/cd": "cicd", "ci cd": "cicd", "ci-cd": "cicd", "ci–cd": "cicd", "ci—cd": "cicd",
    "prometheus": "prometheus", "grafana": "grafana",
    "elk": "elk", "efk": "elk",
    "linux": "linux", "openshift": "openshift",

    # языки/ML‑стек
    "python": "python", "java": "java", "c#": "csharp", "csharp": "csharp",
    "javascript": "javascript", "js": "javascript",
    "sql": "sql",
    "pandas": "pandas", "numpy": "numpy", "scipy": "scipy",
    "scikit-learn": "sklearn", "sklearn": "sklearn",
    "pytorch": "pytorch", "tensorflow": "tensorflow",
    "xgboost": "xgboost", "lightgbm": "lightgbm",
    "matplotlib": "matplotlib",

    # llm/nlp/ai
    "nlp": "nlp", "llm": "llm", "rag": "rag", "openai": "openai", "langchain": "langchain",
    "computer vision": "computer vision", "cv": "computer vision",

    # трекинг/маркетинг
    "appmetrica": "appmetrica", "app metrica": "appmetrica",
    "adjust": "adjust", "adjust (fraud)": "adjust", "adjust.": "adjust", "adjust ": "adjust",
    "fraudscore": "fraudscore", "mytracker": "mytracker",
    "amplitude": "amplitude", "appsflyer": "appsflyer",
}

# ---- СХЛОПЫВАНИЕ SQL: любые варианты ниже превращаем в "sql" ----
SQL_ALIASES = [
    r"\bms\s*sql\b", r"\bmssql\b", r"\bsql\s*server\b",
    r"\bt[\- ]?sql\b", r"\btsql\b",
    r"\bpl[\- ]?sql\b", r"\bplsql\b",
    r"\bpostgres(?:ql)?\b", r"\bpostgres\s*sql\b",
    r"\bmy\s*sql\b", r"\bmysql\b",
    r"\bmaria\s*db\b", r"\bmariadb\b",
    # при желании можно добавить: r"\boracle\b" — но обычно оставляют отдельным стеком
]
SQL_ALIAS_COMPILED = [re.compile(p, re.I) for p in SQL_ALIASES]

# многословные тех‑фразы, которые оставляем даже если >3 слов
MULTIWORD_WHITELIST = {
    "machine learning", "deep learning", "data analysis", "data mining",
    "data warehouse", "site reliability engineer", "feature store",
    "business intelligence", "rest api", "soap api", "user story",
    "a/b тесты", "а/b тесты", "а/а тесты",
    "модель данных", "моделирование бизнес процессов"
}

# «контейнеры» без пользы для общего топа (оставляем в по‑ролям)
EXCLUDE_FROM_OVERALL = {"анализ данных", "data analysis", "devops"}

# паттерны языков/уровней
LANG_PAT  = re.compile(r"\b(английск\w*|english|русск\w*|russian|казахск\w*|kazakh)\b", re.IGNORECASE)
LEVEL_PAT = re.compile(r"\b(a1|a2|b1|b2|c1|c2)\b", re.IGNORECASE)

# мусор/софт/уровни
SKILL_TRASH = {
    "не указано","none","nan","—","-",
    "soft skills","коммуникабельность","ответственность",
    "аналитическое мышление","аналитика",
    "работа с большим объемом информации","деловая переписка","умение работать в коллективе",
    "деловая коммуникация","пунктуальность","внимательность","точность и внимательность к деталям",
    "навыки продаж","работа в команде","умение анализировать","системное мышление","критическое мышление",
    "стратегическое планирование","управление командой","управление проектами","project management",
    "ms office","ms powerpoint","microsoft windows","навыки презентаций","подготовка презентаций",
    "бизнес-анализ","system analysis","системный анализ","business analysis","бизнес-аналитика",
    # уровни владения языком
    "начальный","средний","продвинутый","средне-продвинутый",
    "beginner","elementary","intermediate","upper-intermediate","advanced"
}

ROLE_EMOJI = {
    "Data Analyst":"📈", "Data Scientist":"🧪", "ML Engineer":"🤖",
    "Data Engineer":"🛠", "MLOps":"⚙️", "DevOps":"🧰",
    "BI Analyst":"📊", "Business Analyst":"💼", "System Analyst":"🧩",
}

NBSP_RE = re.compile(r"[\u00A0\u2007\u202F]")
DASH_RE = re.compile(r"[–—]")
RANGE_DASHES = r"[–—-]"

# =========================
# Утилиты очистки
# =========================
def _clean_separators(x: str) -> str:
    x = NBSP_RE.sub(" ", x)
    x = DASH_RE.sub("-", x)
    return x

def _strip_quotes_spaces(x: str) -> str:
    x = re.sub(r"[\"'’«»“”]", " ", x)
    x = re.sub(r"\s+", " ", x).strip()
    return x

def _cut_language_levels(x: str) -> str:
    x_low = x.lower()
    if LANG_PAT.search(x_low):
        x_low = re.split(RANGE_DASHES, x_low)[0].strip()
        return x_low
    return x

def _norm_token(s: str) -> str:
    x = _clean_separators(s)
    x = _strip_quotes_spaces(x)
    x = _cut_language_levels(x)
    x = x.lower()
    x = x.replace(" / ", "/")
    x = re.sub(r"\s*/\s*", "/", x)
    x = re.sub(r"\s*-\s*", "-", x)
    x = re.sub(r"\s+", " ", x).strip()

    # --- СХЛОПЫВАНИЕ SQL: если попадает под любой алиас → "sql"
    if any(p.search(x) for p in SQL_ALIAS_COMPILED):
        return "sql"

    # обычные синонимы
    x = SKILL_SYNONYMS.get(x, x)
    return x

def _is_trash(x: str) -> bool:
    if not x or x in SKILL_TRASH: return True
    if LANG_PAT.search(x): return True
    if LEVEL_PAT.search(x): return True
    if len(x) <= 1 or x.isdigit(): return True
    words = x.split()
    if len(words) > 3 and x not in MULTIWORD_WHITELIST:
        return True
    return False

# =========================
# Разбор колонки skills
# =========================
def explode_skills(df: pd.DataFrame, skills_col: str = "skills") -> pd.DataFrame:
    rows = []
    if skills_col not in df.columns or df[skills_col].isna().all():
        return pd.DataFrame(columns=["row_id","skill"])

    for rid, raw in enumerate(df[skills_col].astype(str).tolist()):
        if not raw or raw.lower().strip() in {"не указано","nan","none",""}:
            continue
        parts = re.split(r"[,\;\|•\n\r]+", raw)
        seen = set()

        for p in parts:
            if re.search(rf"\s{RANGE_DASHES}\s", p):
                for sub in re.split(rf"\s{RANGE_DASHES}\s", p):
                    tok = _norm_token(sub)
                    if not _is_trash(tok) and tok not in seen:
                        rows.append({"row_id": rid, "skill": tok})
                        seen.add(tok)
                continue

            tok = _norm_token(p)
            if _is_trash(tok):
                continue
            if tok not in seen:
                rows.append({"row_id": rid, "skill": tok})
                seen.add(tok)

    return pd.DataFrame(rows)

# =========================
# Топы и тренды
# =========================
def _percent(n, total):
    return 0 if not total else round(n / total * 100)

def _format_items(df_items, total_posts):
    return " • ".join([f"{r.skill} — {int(r.count)} ({_percent(r.count, total_posts)}%)"
                       for r in df_items.itertuples(index=False)])

def top_overall(df: pd.DataFrame, skills_col="skills", topn=10) -> pd.DataFrame:
    s = explode_skills(df, skills_col)
    if s.empty:
        return pd.DataFrame(columns=["skill","count"])
    vc = (s.groupby("skill")["row_id"].nunique().rename("count").reset_index())
    vc = vc[~vc["skill"].isin(EXCLUDE_FROM_OVERALL)]
    vc = vc.sort_values("count", ascending=False).head(topn)
    return vc

def top_by_role(df: pd.DataFrame, skills_col="skills", role_col="canonical_role", topn=5, roles_order=None):
    if role_col not in df.columns:
        return []
    s = explode_skills(df, skills_col)
    if s.empty:
        return []
    s = s.merge(
        df[[role_col]].reset_index(drop=True).rename(columns={role_col: "role"}),
        left_on="row_id", right_index=True, how="left"
    )

    out = []
    if not roles_order:
        roles_order = ["Data Analyst","Data Scientist","ML Engineer","Data Engineer","MLOps","DevOps","BI Analyst","Business Analyst","System Analyst"]
    for role in roles_order:
        g = s[s["role"] == role]
        if g.empty:
            continue
        vc = (g.groupby("skill")["row_id"].nunique()
                .sort_values(ascending=False)
                .head(topn)
                .rename("count")
                .reset_index())
        out.append((role, vc, int(g["row_id"].nunique())))
    return out

def universal_skills_by_roles(df: pd.DataFrame, skills_col="skills", role_col="canonical_role", min_roles=3):
    if role_col not in df.columns:
        return pd.DataFrame(columns=["skill","roles"])
    s = explode_skills(df, skills_col)
    if s.empty:
        return pd.DataFrame(columns=["skill","roles"])
    s = s.merge(
        df[[role_col]].reset_index(drop=True).rename(columns={role_col: "role"}),
        left_on="row_id", right_index=True, how="left"
    ).dropna(subset=["role"])

    role_sets = s.groupby("skill")["role"].apply(lambda x: set(x.dropna()))
    out = (role_sets[role_sets.apply(len) >= min_roles]
           .reset_index().rename(columns={"role":"roles"}))
    out["roles_count"] = out["roles"].apply(len)
    out = out.sort_values(["roles_count","skill"], ascending=[False,True]).reset_index(drop=True)
    return out

def week_trend(df: pd.DataFrame, skills_col="skills", date_col="published_at", topn=6):
    if date_col not in df.columns:
        return None

    today = pd.Timestamp(date.today())
    start_this = today - pd.Timedelta(days=6)
    start_prev = start_this - pd.Timedelta(days=7)
    end_prev   = start_this - pd.Timedelta(days=1)

    dfx = df.copy()
    dfx[date_col] = pd.to_datetime(dfx[date_col], errors="coerce")
    cur = dfx[(dfx[date_col] >= start_this) & (dfx[date_col] <= today)]
    prv = dfx[(dfx[date_col] >= start_prev) & (dfx[date_col] <= end_prev)]
    if cur.empty or prv.empty:
        return None

    s_cur = explode_skills(cur, skills_col)
    s_prv = explode_skills(prv, skills_col)
    if s_cur.empty or s_prv.empty:
        return None

    cur_vc = s_cur.groupby("skill")["row_id"].nunique().rename("cur")
    prv_vc = s_prv.groupby("skill")["row_id"].nunique().rename("prv")
    merged = (pd.concat([cur_vc, prv_vc], axis=1).fillna(0).astype(int))
    merged["delta"] = merged["cur"] - merged["prv"]

    gainers = (merged.sort_values("delta", ascending=False)
                      .head(topn)
                      .reset_index().rename(columns={"index":"skill"}))
    losers  = (merged.sort_values("delta", ascending=True)
                      .head(topn)
                      .reset_index().rename(columns={"index":"skill"}))
    return {"gainers": gainers, "losers": losers}

# =========================
# Формирование текста для ТГ
# =========================
def make_skills_report(df: pd.DataFrame, skills_col="skills", role_col="canonical_role",
                       top_overall_n=12, top_role_n=6, min_roles_universal=3,
                       date_col="published_at") -> str:
    total_posts = int(len(df))
    s_exp = explode_skills(df, skills_col)
    posts_with_sk = int(s_exp.row_id.nunique()) if not s_exp.empty else 0
    share = f"{(posts_with_sk/total_posts*100):.0f}%" if total_posts else "0%"

    overall = top_overall(df, skills_col=skills_col, topn=top_overall_n)
    overall_txt = _format_items(overall, max(posts_with_sk, 1)) if not overall.empty else "—"

    role_blocks = []
    cover_lines = []
    for role, tab, role_posts_with_sk in top_by_role(df, skills_col=skills_col, role_col=role_col, topn=top_role_n):
        emoji = ROLE_EMOJI.get(role, "•")
        line = " • ".join([f"{r.skill} — {int(r.count)} ({_percent(r.count, max(role_posts_with_sk,1))}%)"
                           for r in tab.itertuples(index=False)])
        role_blocks.append(f"{emoji} {role}: {line}")
        role_total = int((df[role_col] == role).sum())
        cover = f"{role}: {role_posts_with_sk}/{role_total} ({_percent(role_posts_with_sk, max(role_total,1))}%)"
        cover_lines.append(cover)
    roles_txt = "\n".join(role_blocks) if role_blocks else "—"
    covers_txt = " • ".join(cover_lines) if cover_lines else "—"

    uni = universal_skills_by_roles(df, skills_col=skills_col, role_col=role_col, min_roles=min_roles_universal)
    uni_txt = " • ".join([f"{r.skill} ({len(r.roles)})" for r in uni.itertuples(index=False)]) if not uni.empty else "—"

    trend_txt = ""
    tr = week_trend(df, skills_col=skills_col, date_col=date_col, topn=6)
    if tr:
        up_line = " • ".join([f"{r.skill} (▲ {int(r.delta)})" for r in tr["gainers"].itertuples(index=False)])
        dn_line = " • ".join([f"{r.skill} (▼ {abs(int(r.delta))})" for r in tr["losers"].itertuples(index=False)])
        trend_txt = f"\n📈 Растут: {up_line}\n📉 Падают: {dn_line}\n"

    return (
        "🏆 Топ навыков (неделя)\n"
        f"{overall_txt}\n\n"
        "📌 По направлениям\n"
        f"{roles_txt}\n\n"
        f"🧭 Универсальные навыки (в ≥{min_roles_universal} ролях)\n"
        f"{uni_txt}\n\n"
        f"🧩 Покрытие по ролям (вакансии со скиллами / все)\n"
        f"{covers_txt}\n"
        f"{trend_txt}"
        f"Всего вакансий: {total_posts} • Со скиллами: {posts_with_sk} ({share})\n"
        "#skills #вакансии"
    )

# %%
text = make_skills_report(df)
print(text)
# Out:
# 🏆 Топ навыков (неделя)
# sql — 222 (53%) • python — 149 (36%) • powerbi — 84 (20%) • docker — 60 (14%) • linux — 59 (14%) • excel — 55 (13%) • kubernetes — 48 (11%) • bpmn — 42 (10%) • git — 39 (9%) • uml — 38 (9%) • terraform — 34 (8%) • etl — 32 (8%)
#
# 📌 По направлениям
# 📈 Data Analyst: sql — 65 (67%) • powerbi — 49 (51%) • python — 38 (39%) • анализ данных — 34 (35%) • excel — 32 (33%) • визуализация данных — 9 (9%)
# 🧪 Data Scientist: sql — 14 (74%) • python — 13 (68%) • big data — 9 (47%) • data analysis — 6 (32%) • nlp — 5 (26%) • ml — 5 (26%)
# 🤖 ML Engineer: python — 16 (70%) • sql — 7 (30%) • tensorflow — 6 (26%) • sklearn — 4 (17%) • git — 4 (17%) • pytorch — 4 (17%)
# 🛠 Data Engineer: sql — 24 (89%) • python — 16 (59%) • etl — 13 (48%) • airflow — 5 (19%) • big data — 5 (19%) • git — 5 (19%)
# ⚙️ MLOps: cicd — 2 (100%) • grafana — 2 (100%) • prometheus — 2 (100%) • airflow — 1 (50%) • api — 1 (50%) • docker — 1 (50%)
# 🧰 DevOps: docker — 55 (67%) • linux — 55 (67%) • kubernetes — 44 (54%) • devops — 41 (50%) • terraform — 33 (40%) • python — 33 (40%)
# 📊 BI Analyst: sql — 16 (89%) • powerbi — 12 (67%) • etl — 7 (39%) • анализ данных — 5 (28%) • tableau — 5 (28%) • python — 4 (22%)
# 💼 Business Analyst: sql — 9 (31%) • powerbi — 9 (31%) • excel — 8 (28%) • описание бизнес-процессов — 7 (24%) • моделирование бизнес-процессов — 6 (21%) • bpmn — 6 (21%)
# 🧩 System Analyst: bpmn — 33 (57%) • sql — 30 (52%) • uml — 29 (50%) • постановка задач разработчикам — 15 (26%) • atlassian confluence — 13 (22%) • atlassian jira — 13 (22%)
#
# 🧭 Универсальные навыки (в ≥3 ролях)
# python (12) • sql (12) • powerbi (9) • в совершенстве (8) • data analysis (7) • etl (7) • excel (7) • tableau (7) • анализ данных (7) • математическая статистика (7) • api (6) • uml (6) • big data (5) • cicd (5) • clickhouse (5) • docker (5) • git (5) • kubernetes (5) • pandas (5) • анализ требований (5) • базы данных (5) • визуализация данных (5) • исследовательский анализ данных (5) • airflow (4) • bigquery (4) • bpmn (4) • devops (4) • dwh (4) • grafana (4) • kafka (4) • linux (4) • machine learning (4) • nosql (4) • qlik (4) • постановка задач разработчикам (4) • разработка технических заданий (4) • управленческая отчетность (4) • финансовая отчетность (4) • agile (3) • ai (3) • aws (3) • azure (3) • crm (3) • data science (3) • gitlab (3) • java (3) • javascript (3) • jupyter notebook (3) • numpy (3) • powerquery (3) • sdlc (3) • user story (3) • анализ бизнес-процессов (3) • анализ рынка (3) • аналитика продаж (3) • информационные технологии (3) • конкурентная аналитика (3) • маркетинговые исследования (3) • машинное обучение (3) • моделирование бизнес процессов (3) • моделирование бизнес-процессов (3) • описание бизнес-процессов (3) • прогнозирование (3) • разработка бизнес-требований (3) • разработка по (3) • статистический анализ (3) • финансовый анализ (3) • формирование аналитической отчетности (3) • экономический анализ (3) • элементарный (3)
#
# 🧩 Покрытие по ролям (вакансии со скиллами / все)
# Data Analyst: 97/177 (55%) • Data Scientist: 19/37 (51%) • ML Engineer: 23/33 (70%) • Data Engineer: 27/60 (45%) • MLOps: 2/4 (50%) • DevOps: 82/124 (66%) • BI Analyst: 18/31 (58%) • Business Analyst: 29/57 (51%) • System Analyst: 58/122 (48%)
#
# 📈 Растут: xml (▲ 3) • bpmn (▲ 3) • json (▲ 2) • формирование аналитической отчетности (▲ 2) • qlik (▲ 2) • математический анализ (▲ 2)
# 📉 Падают: sql (▼ 8) • python (▼ 8) • powerbi (▼ 8) • анализ данных (▼ 5) • kubernetes (▼ 5) • docker (▼ 5)
# Всего вакансий: 740 • Со скиллами: 418 (56%)
# #skills #вакансии

# %%
# weekly_report.py
import os
import re
import psycopg2
import pandas as pd
from datetime import date, timedelta
from dotenv import load_dotenv

# ---- твои роли (берём из проекта) ----
from src.config import ROLE_KEYWORDS, OTHER_LABEL

load_dotenv()

# =========================
# Подключение к БД
# =========================
def connect_to_db():
    db_url = os.getenv("DATABASE_URL")
    if not db_url:
        raise ValueError("Url of DB is not set")
    return psycopg2.connect(db_url, sslmode="require")

# =========================
# Нормализация и маппинг ролей
# =========================
def pre_normalize(s: str) -> str:
    if not isinstance(s, str):
        return ""
    s = s.strip()
    s = re.sub(r"\b(trainee|стаж[её]р|интерн)\b", " intern ", s, flags=re.I)
    s = re.sub(r"\b(head of|руководител[ья]|team\s*lead|lead|лид)\b", " lead ", s, flags=re.I)
    s = s.replace("-", "-").replace("–", "-").replace("—", "-").replace("ё", "е")
    return s

def normalize_text(s: str) -> str:
    s = pre_normalize(s)
    s = s.lower()
    s = re.sub(r"[^\w\s+/\-]+", " ", s, flags=re.UNICODE)
    s = re.sub(r"\s+", " ", s).strip()
    return s

ROLE_PATTERNS = [
    (role, [re.compile(pat, re.IGNORECASE) for pat in pats])
    for role, pats in ROLE_KEYWORDS.items()
]

def map_role_by_keywords(title: str) -> str:
    t = normalize_text(title)
    for role, patterns in ROLE_PATTERNS:
        for pat in patterns:
            if pat.search(t):
                return role
    return OTHER_LABEL

# =========================
# Блок по SKILLS (нормализация и аналитика)
# =========================
SKILL_SYNONYMS = {
    # облака
    "amazon web services": "aws", "aws": "aws",
    "microsoft azure": "azure", "azure": "azure",
    "google cloud": "gcp", "google cloud platform": "gcp", "gcp": "gcp",

    # BI / аналитика
    "power bi": "powerbi", "ms power bi": "powerbi", "microsoft power bi": "powerbi",
    "powerbi": "powerbi", "power-bi": "powerbi",
    "qlik sense": "qlik", "qlikview": "qlik", "qlick": "qlik", "qlik": "qlik",
    "looker studio": "looker", "google data studio": "looker", "looker": "looker",
    "metabase": "metabase", "apache superset": "superset", "superset": "superset",
    "tableau": "tableau",
    "power query": "powerquery", "powerquery": "powerquery", "dax": "dax",

    # офис
    "ms excel": "excel", "microsoft excel": "excel", "excel": "excel",

    # платформы/оркестрация/хранилища (без SQL — схлопаем отдельно)
    "clickhouse": "clickhouse", "greenplum": "greenplum",
    "snowflake": "snowflake", "redshift": "redshift", "bigquery": "bigquery",
    "data warehouse": "dwh", "кхд": "dwh", "dwh": "dwh",
    "dbt": "dbt",
    "apache airflow": "airflow", "airflow": "airflow",
    "apache kafka": "kafka", "kafka": "kafka",
    "apache nifi": "nifi", "nifi": "nifi",
    "spark": "spark", "apache spark": "spark", "pyspark": "pyspark",

    # devops
    "docker": "docker",
    "kubernetes": "kubernetes", "k8s": "kubernetes",
    "helm": "helm", "terraform": "terraform", "ansible": "ansible",
    "jenkins": "jenkins", "zabbix": "zabbix",
    "gitlab ci": "gitlabci", "gitlab-ci": "gitlabci", "gitlabci": "gitlabci",
    "ci/cd": "cicd", "ci cd": "cicd", "ci-cd": "cicd", "ci–cd": "cicd", "ci—cd": "cicd",
    "prometheus": "prometheus", "grafana": "grafana",
    "elk": "elk", "efk": "elk",
    "linux": "linux", "openshift": "openshift",

    # языки/ML‑стек
    "python": "python", "java": "java", "c#": "csharp", "csharp": "csharp",
    "javascript": "javascript", "js": "javascript",
    "sql": "sql",
    "pandas": "pandas", "numpy": "numpy", "scipy": "scipy",
    "scikit-learn": "sklearn", "sklearn": "sklearn",
    "pytorch": "pytorch", "tensorflow": "tensorflow",
    "xgboost": "xgboost", "lightgbm": "lightgbm",
    "matplotlib": "matplotlib",

    # llm/nlp/ai
    "nlp": "nlp", "llm": "llm", "rag": "rag", "openai": "openai", "langchain": "langchain",
    "computer vision": "computer vision", "cv": "computer vision",

    # трекинг/маркетинг
    "appmetrica": "appmetrica", "app metrica": "appmetrica",
    "adjust": "adjust", "adjust (fraud)": "adjust", "adjust.": "adjust", "adjust ": "adjust",
    "fraudscore": "fraudscore", "mytracker": "mytracker",
    "amplitude": "amplitude", "appsflyer": "appsflyer",
}

# любые варианты ниже превращаем в "sql"
SQL_ALIASES = [
    r"\bms\s*sql\b", r"\bmssql\b", r"\bsql\s*server\b",
    r"\bt[\-\s]?sql\b", r"\btsql\b",
    r"\bpl[\-\s]?sql\b", r"\bplsql\b",
    r"\bpostgres(?:ql)?\b", r"\bpostgres\s*sql\b",
    r"\bmy\s*sql\b", r"\bmysql\b",
    r"\bmaria\s*db\b", r"\bmariadb\b",
]
SQL_ALIAS_COMPILED = [re.compile(p, re.I) for p in SQL_ALIASES]

# «контейнеры», которые не показываем в общем топе (оставим для разрезов)
EXCLUDE_FROM_OVERALL = {"анализ данных", "data analysis", "devops"}

LANG_PAT  = re.compile(r"\b(английск\w*|english|русск\w*|russian|казахск\w*|kazakh)\b", re.IGNORECASE)
LEVEL_PAT = re.compile(r"\b(a1|a2|b1|b2|c1|c2)\b", re.IGNORECASE)

SKILL_TRASH = {
    "не указано","none","nan","—","-",
    "soft skills","коммуникабельность","ответственность","аналитическое мышление","аналитика",
    "работа с большим объемом информации","деловая переписка","умение работать в коллективе",
    "деловая коммуникация","пунктуальность","внимательность","точность и внимательность к деталям",
    "навыки продаж","работа в команде","умение анализировать","системное мышление","критическое мышление",
    "стратегическое планирование","управление командой","управление проектами","project management",
    "ms office","ms powerpoint","microsoft windows","навыки презентаций","подготовка презентаций",
    "бизнес-анализ","system analysis","системный анализ","business analysis","бизнес-аналитика",
    "начальный","средний","продвинутый","средне-продвинутый",
    "beginner","elementary","intermediate","upper-intermediate","advanced",
}

NBSP_RE = re.compile(r"[\u00A0\u2007\u202F]")
DASH_RE = re.compile(r"[–—]")
RANGE_DASHES = r"[–—-]"

def _clean_separators(x: str) -> str:
    x = NBSP_RE.sub(" ", x)
    x = DASH_RE.sub("-", x)
    return x

def _strip_quotes_spaces(x: str) -> str:
    x = re.sub(r"[\"'’«»“”]", " ", x)
    x = re.sub(r"\s+", " ", x).strip()
    return x

def _cut_language_levels(x: str) -> str:
    x_low = x.lower()
    if LANG_PAT.search(x_low):
        x_low = re.split(RANGE_DASHES, x_low)[0].strip()
        return x_low
    return x

def _norm_token(s: str) -> str:
    x = _clean_separators(s)
    x = _strip_quotes_spaces(x)
    x = _cut_language_levels(x)
    x = x.lower()
    x = x.replace(" / ", "/")
    x = re.sub(r"\s*/\s*", "/", x)
    x = re.sub(r"\s*-\s*", "-", x)
    x = re.sub(r"\s+", " ", x).strip()

    # SQL: если любой алиас совпал — сворачиваем в "sql"
    if any(p.search(x) for p in SQL_ALIAS_COMPILED):
        return "sql"

    # обычные синонимы
    x = SKILL_SYNONYMS.get(x, x)
    return x

def _is_trash(x: str) -> bool:
    if not x or x in SKILL_TRASH: return True
    if LANG_PAT.search(x): return True
    if LEVEL_PAT.search(x): return True
    if len(x) <= 1 or x.isdigit(): return True
    words = x.split()
    if len(words) > 3 and x not in {
        "machine learning", "deep learning", "data analysis", "data mining",
        "data warehouse", "site reliability engineer", "feature store",
        "business intelligence", "rest api", "soap api", "user story",
        "a/b тесты", "а/b тесты", "а/а тесты",
        "модель данных", "моделирование бизнес процессов",
    }:
        return True
    return False

def explode_skills(df: pd.DataFrame, skills_col: str = "skills") -> pd.DataFrame:
    rows = []
    if skills_col not in df.columns or df[skills_col].isna().all():
        return pd.DataFrame(columns=["row_id","skill"])

    for rid, raw in enumerate(df[skills_col].astype(str).tolist()):
        if not raw or raw.lower().strip() in {"не указано","nan","none",""}:
            continue
        parts = re.split(r"[,\;\|•\n\r]+", raw)
        seen = set()

        for p in parts:
            # если "SQL — Power BI" -> делим по тире на 2 токена
            if re.search(rf"\s{RANGE_DASHES}\s", p):
                for sub in re.split(rf"\s{RANGE_DASHES}\s", p):
                    tok = _norm_token(sub)
                    if not _is_trash(tok) and tok not in seen:
                        rows.append({"row_id": rid, "skill": tok})
                        seen.add(tok)
                continue

            tok = _norm_token(p)
            if _is_trash(tok):
                continue
            if tok not in seen:
                rows.append({"row_id": rid, "skill": tok})
                seen.add(tok)

    return pd.DataFrame(rows)

def _percent(n, total):
    return 0 if not total else round(n / total * 100)

def _format_items(df_items, total_posts):
    # пример: "sql — 57 (25%) • python — 49 (21%)"
    return " • ".join([f"{r.skill} — {int(r.count)} ({_percent(r.count, total_posts)}%)"
                       for r in df_items.itertuples(index=False)])

def top_overall(df: pd.DataFrame, skills_col="skills", topn=12) -> pd.DataFrame:
    s = explode_skills(df, skills_col)
    if s.empty:
        return pd.DataFrame(columns=["skill","count"])
    # считаем по числу вакансий, где встречается навык (а не по общим упоминаниям)
    vc = (s.groupby("skill")["row_id"].nunique().rename("count").reset_index())
    vc = vc[~vc["skill"].isin(EXCLUDE_FROM_OVERALL)]
    vc = vc.sort_values("count", ascending=False).head(topn)
    return vc

def top_by_role(df: pd.DataFrame, skills_col="skills", role_col="canonical_role", topn=6, roles_order=None):
    if role_col not in df.columns:
        return []
    s = explode_skills(df, skills_col)
    if s.empty:
        return []
    s = s.merge(
        df[[role_col]].reset_index(drop=True).rename(columns={role_col: "role"}),
        left_on="row_id", right_index=True, how="left"
    )

    out = []
    if not roles_order:
        roles_order = [
            "Data Analyst","Data Scientist","ML Engineer","Data Engineer",
            "MLOps","DevOps","BI Analyst","Business Analyst","System Analyst"
        ]
    for role in roles_order:
        g = s[s["role"] == role]
        if g.empty:
            continue
        vc = (g.groupby("skill")["row_id"].nunique()
                .sort_values(ascending=False)
                .head(topn)
                .rename("count")
                .reset_index())
        out.append((role, vc, int(g["row_id"].nunique())))  # добавим покрытие по роли
    return out

def universal_skills_by_roles(df: pd.DataFrame, skills_col="skills", role_col="canonical_role", min_roles=3):
    if role_col not in df.columns:
        return pd.DataFrame(columns=["skill","roles"])
    s = explode_skills(df, skills_col)
    if s.empty:
        return pd.DataFrame(columns=["skill","roles"])
    s = s.merge(
        df[[role_col]].reset_index(drop=True).rename(columns={role_col: "role"}),
        left_on="row_id", right_index=True, how="left"
    ).dropna(subset=["role"])

    role_sets = s.groupby("skill")["role"].apply(lambda x: set(x.dropna()))
    out = (role_sets[role_sets.apply(len) >= min_roles]
           .reset_index().rename(columns={"role":"roles"}))
    out["roles_count"] = out["roles"].apply(len)
    out = out.sort_values(["roles_count","skill"], ascending=[False,True]).reset_index(drop=True)
    return out

def week_trend(df: pd.DataFrame, skills_col="skills", date_col="published_at", topn=6):
    if date_col not in df.columns:
        return None

    today = pd.Timestamp(date.today())
    start_this = today - pd.Timedelta(days=6)      # последние 7 дней
    start_prev = start_this - pd.Timedelta(days=7) # предыдущая неделя
    end_prev   = start_this - pd.Timedelta(days=1)

    dfx = df.copy()
    dfx[date_col] = pd.to_datetime(dfx[date_col], errors="coerce")
    cur = dfx[(dfx[date_col] >= start_this) & (dfx[date_col] <= today)]
    prv = dfx[(dfx[date_col] >= start_prev) & (dfx[date_col] <= end_prev)]
    if cur.empty or prv.empty:
        return None

    s_cur = explode_skills(cur, skills_col)
    s_prv = explode_skills(prv, skills_col)
    if s_cur.empty or s_prv.empty:
        return None

    cur_vc = s_cur.groupby("skill")["row_id"].nunique().rename("cur")
    prv_vc = s_prv.groupby("skill")["row_id"].nunique().rename("prv")
    merged = (pd.concat([cur_vc, prv_vc], axis=1).fillna(0).astype(int))
    merged["delta"] = merged["cur"] - merged["prv"]

    gainers = (merged.sort_values("delta", ascending=False)
                      .head(topn)
                      .reset_index().rename(columns={"index":"skill"}))
    losers  = (merged.sort_values("delta", ascending=True)
                      .head(topn)
                      .reset_index().rename(columns={"index":"skill"}))
    return {"gainers": gainers, "losers": losers}

# =========================
# ЕДИНЫЙ ОТЧЁТ (Профили + Скиллы)
# =========================
def make_full_report(df: pd.DataFrame,
                     skills_col: str = "skills",
                     role_col: str = "canonical_role",
                     date_col: str = "published_at",
                     top_overall_n: int = 12,
                     top_role_n: int = 6,
                     min_roles_universal: int = 3) -> str:
    # ---- Профили (доли по ролям)
    total = int(df.shape[0])
    counts = (
        df[role_col]
        .value_counts(dropna=False)
        .rename_axis("role")
        .reset_index(name="count")
        .sort_values(["count", "role"], ascending=[False, True])
    )
    counts["percent"] = (counts["count"] / total * 100).round(1) if total else 0.0
    roles_lines = [f"- {row['role']} — {row['percent']}%" for _, row in counts.iterrows()]
    profiles_block = "📊 Профили (неделя)\n" + ("\n".join(roles_lines) if roles_lines else "—")

    # ---- Скиллы (общий топ)
    overall = top_overall(df, skills_col=skills_col, topn=top_overall_n)
    s_exp = explode_skills(df, skills_col)
    posts_with_sk = int(s_exp.row_id.nunique()) if not s_exp.empty else 0
    share = f"{(posts_with_sk/total*100):.0f}%" if total else "0%"
    overall_txt = _format_items(overall, max(posts_with_sk, 1)) if not overall.empty else "—"
    skills_top_block = f"🏆 Топ навыков (неделя)\n{overall_txt}"

    # ---- По ролям
    role_blocks = []
    cover_lines = []
    ROLES_EMOJI = {
        "Data Analyst":"📈","Data Scientist":"🧪","ML Engineer":"🤖",
        "Data Engineer":"🛠","MLOps":"⚙️","DevOps":"🧰",
        "BI Analyst":"📊","Business Analyst":"💼","System Analyst":"🧩",
    }
    for role, tab, role_posts_with_sk in top_by_role(df, skills_col=skills_col, role_col=role_col, topn=top_role_n):
        emoji = ROLES_EMOJI.get(role, "•")
        line = " • ".join([f"{r.skill} — {int(r.count)} ({_percent(r.count, max(role_posts_with_sk,1))}%)"
                           for r in tab.itertuples(index=False)])
        role_blocks.append(f"{emoji} {role}: {line}")
        role_total = int((df[role_col] == role).sum())
        cover_lines.append(f"{role}: {role_posts_with_sk}/{role_total} ({_percent(role_posts_with_sk, max(role_total,1))}%)")
    roles_txt = "\n".join(role_blocks) if role_blocks else "—"
    covers_txt = " • ".join(cover_lines) if cover_lines else "—"
    skills_roles_block = f"📌 По направлениям\n{roles_txt}\n\n🧩 Покрытие по ролям (со скиллами / все)\n{covers_txt}"

    # ---- Универсальные навыки
    uni = universal_skills_by_roles(df, skills_col=skills_col, role_col=role_col, min_roles=min_roles_universal)
    uni_txt = " • ".join([f"{r.skill} ({len(r.roles)})" for r in uni.itertuples(index=False)]) if not uni.empty else "—"
    skills_uni_block = f"🧭 Универсальные навыки (в ≥{min_roles_universal} ролях)\n{uni_txt}"

    # ---- Тренды недели (если есть дата)
    trend_txt = ""
    tr = week_trend(df, skills_col=skills_col, date_col=date_col, topn=6)
    if tr:
        up_line = " • ".join([f"{r.skill} (▲ {int(r.delta)})" for r in tr["gainers"].itertuples(index=False)])
        dn_line = " • ".join([f"{r.skill} (▼ {abs(int(r.delta))})" for r in tr["losers"].itertuples(index=False)])
        trend_txt = f"\n📈 Растут: {up_line}\n📉 Падают: {dn_line}"

    # ---- Итог и сводка
    header = "Еженедельный отчёт по вакансиям\n"
    footer = f"\nВсего вакансий: {total} • Со скиллами: {posts_with_sk} ({share})\n#вакансии #skills"
    return (
        header
        + profiles_block + "\n\n"
        + skills_top_block + "\n\n"
        + skills_roles_block + "\n\n"
        + skills_uni_block
        + trend_txt
        + footer
    )

# =========================
# MAIN
# =========================
if __name__ == "__main__":
    today = date.today()
    week = today - timedelta(days=7)
    print(f"from {week} to {today}")

    conn = connect_to_db()
    # Если хочешь фильтровать прямо в SQL по дате публикации — раскомментируй и проверь имя колонки
    # query = "SELECT * FROM vacancies WHERE published_at BETWEEN %s AND %s"
    # df = pd.read_sql(query, conn, params=(week, today))
    query = "SELECT * FROM vacancies"
    df = pd.read_sql(query, conn)
    conn.close()

    # Маппинг ролей
    df["canonical_role"] = df["title"].astype(str).apply(map_role_by_keywords)

    # (необязательно) сохранить "несопоставленные" для ручного анализа:
    # df[df['canonical_role'] == OTHER_LABEL][['title']].to_csv("other_roles.csv", index=False)

    # Собрать текст отчёта
    report_text = make_full_report(
        df,
        skills_col="skills",
        role_col="canonical_role",
        date_col="published_at",
        top_overall_n=12,
        top_role_n=6,
        min_roles_universal=3,
    )
    print("\n" + "="*80 + "\n")
    print(report_text)
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[56], line 10
#       7 from dotenv import load_dotenv
#       9 # ---- твои роли (берём из проекта) ----
# ---> 10 from src.config import ROLE_KEYWORDS, OTHER_LABEL
#      12 load_dotenv()
#      14 # =========================
#      15 # Подключение к БД
#      16 # =========================
#
# ModuleNotFoundError: No module named 'src'
