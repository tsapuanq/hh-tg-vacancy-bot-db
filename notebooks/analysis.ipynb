# %%
import pandas as pd

# %%
df = pd.read_csv(r"C:\Users\User\hh_data_project\data\raw\vacancies.csv")
df.head()
# Out:
#                                                title  \
# 0               Junior Data Scientist/Data Scientist
# 1                        Junior Data Scientist (NLP)
# 2                                     Data Scientist
# 3  Data Scientist по направлению Антифрод/anti-fraud
# 4  Data Scientist Дирекции моделирования кредитны...
#
#                                            company  \
# 0                            Nazarbayev University
# 1                                      Beeline, ТМ
# 2  Публичная Компания «Freedom Finance Global PLC»
# 3  Публичная Компания «Freedom Finance Global PLC»
# 4                              АО Банк ЦентрКредит
#
#                                          location      salary  \
# 0                                      Не указано  Не указано
# 1                                      Не указано  Не указано
# 2                                      Не указано  Не указано
# 3                                      Не указано  Не указано
# ...

# %%
df['description'][8]
# Out:
# 'Просим не откликаться на вакансию граждан других стран, удаленной работы нет!\n\nОбязанности:\n\nАнализ данных и их интерпретация: сбор, обработка и систематизация данных из различных источников;\nпроведение статистического анализа для выявления закономерностей, тенденций в данных;\nисследования, тестирование гипотез, реализация и развитие Big DATA, перевод на модель по принятию решений на основе данных;\nпостроение прогнозных моделей для оценки экономической динамики и принятия управленческих решений;\nсоздание эконометрических и статистических моделей для анализа данных, применение методов машинного обучения и других алгоритмов анализа больших данных (Big Data) для решения экономических задач;\nмоделирование сценариев развития экономики, включая оценку влияния макроэкономических и микроэкономических факторов;\nразработка визуализаций данных (графиков, диаграмм, интерактивных дашбордов)для представления результатов аналитики;\nподготовка аналитических отчетов, презентаций с рекомен
# ...

# %%
df['work_format'].unique()
# Out:
# array(['Формат работы: на месте работодателя', 'Не указано',
#        'Формат работы: гибрид',
#        'Формат работы: на месте работодателя или гибрид',
#        'Формат работы: удалённо'], dtype=object)

# %%
df
# Out:
#                                                 title  \
# 0                Junior Data Scientist/Data Scientist
# 1                         Junior Data Scientist (NLP)
# 2                                      Data Scientist
# 3   Data Scientist по направлению Антифрод/anti-fraud
# 4   Data Scientist Дирекции моделирования кредитны...
# 5                                      Data Scientist
# 6                        Агроном / Начинающий агроном
# 7                                      Data Scientist
# 8                     Data Scientist (Middle, Senior)
# 9                               Senior Data Scientist
# 10                                 AI Data Group Lead
# 11                      Data Scientist Middle+/Senior
# 12      Data Scientist в Департамент кредитных рисков
# 13           Senior Data Software Engineer (Big Data)
# 14  Senior Data Scientist в Департамент кредитных ...
# 15                                     Data Scientist
# ...

# %%
df.describe()
# Out:
#                  title                                          company  \
# count               19                                               19
# unique              15                                               15
# top     Data Scientist  Публичная Компания «Freedom Finance Global PLC»
# freq                 4                                                2
#
#           location      salary  \
# count           19          19
# unique           7           2
# top     Не указано  Не указано
# freq            13          18
#
#                                               description  \
# count                                                  19
# unique                                                 18
# top     We are looking for an experienced Senior Data ...
# freq                                                    2
#
#                                                      link experience  \
# count                                                  19         19
# ...
