# %%
import os

os.environ["GEM_API_TOKEN"] = "AIzaSyBID-Oxfqxkp2UdrMtL6l6gdvCSPLAa558"

# %%
import os
import requests
import json

# Пример кода для тестирования Gemini API в Jupyter Notebook

GEMINI_API_KEY = os.getenv("GEM_API_TOKEN")  # обязательно должно быть установлено
GEMINI_API_URL = "https://generativelanguage.googleapis.com/v1beta/models/gemini-2.0-flash:generateContent"
HEADERS = {"Content-Type": "application/json"}

# Простой тестовый промпт
prompt = """
Разбей текст описания вакансии на три блока:
1. О компании
2. Обязанности
3. Требования

Если блока нет — напиши "Не указано".

📌 Верни ЧИСТЫЙ JSON с ключами: about_company, responsibilities, requirements.

Описание:
Компания занимается разработкой систем машинного обучения. Обязанности включают настройку пайплайнов данных и обучение моделей. Требуется опыт с Python, ML и знание PyTorch.
"""

def test_gemini_api(prompt, key):
    if not key:
        return "❌ Переменная окружения GEM_API_TOKEN не установлена"

    try:
        response = requests.post(
            f"{GEMINI_API_URL}?key={key}",
            headers=HEADERS,
            json={"contents": [{"parts": [{"text": prompt}]}]},
            timeout=20,
        )
        response.raise_for_status()
        raw = response.json()
        return json.dumps(raw, indent=2, ensure_ascii=False)
    except Exception as e:
        return f"❌ Ошибка запроса: {e}"

# Выполняем тестовый запрос
test_gemini_api(prompt, GEMINI_API_KEY)
# Out:
# '{\n  "candidates": [\n    {\n      "content": {\n        "parts": [\n          {\n            "text": "```json\\n{\\n  \\"about_company\\": \\"Компания занимается разработкой систем машинного обучения.\\",\\n  \\"responsibilities\\": \\"Обязанности включают настройку пайплайнов данных и обучение моделей.\\",\\n  \\"requirements\\": \\"Требуется опыт с Python, ML и знание PyTorch.\\"\\n}\\n```\\n"\n          }\n        ],\n        "role": "model"\n      },\n      "finishReason": "STOP",\n      "avgLogprobs": -0.0050589341512868105\n    }\n  ],\n  "usageMetadata": {\n    "promptTokenCount": 111,\n    "candidatesTokenCount": 71,\n    "totalTokenCount": 182,\n    "promptTokensDetails": [\n      {\n        "modality": "TEXT",\n        "tokenCount": 111\n      }\n    ],\n    "candidatesTokensDetails": [\n      {\n        "modality": "TEXT",\n        "tokenCount": 71\n      }\n    ]\n  },\n  "modelVersion": "gemini-2.0-flash"\n}'

# %%
import pandas as pd
df1 = pd.read_csv("C:/Users/User/hh_data_project/data/main.csv")

# %%
df1
# Out:
#                                                 title  \
# 0                             Data Engineer (Middle+)
# 1                               Junior Data Scientist
# 2                     Data Scientist (Middle, Senior)
# 3                Data Scientist / Разработчик AI-бота
# 4                                      Data Scientist
# 5                                      Data Scientist
# 6                          Data Scientist ML (Ментор)
# 7                     Data Scientist (Middle, Senior)
# 8                                       Data Engineer
# 9   Data Scientist по направлению Антифрод/anti-fraud
# 10                              Senior Data Scientist
# 11                                 AI Data Group Lead
# 12                                 AI Data Group Lead
# 13                      Data Scientist Middle+/Senior
# 14                           MLOps AWS/Data Scientist
# 15  Data Scientist Дирекции моделирования кредитны...
# ...
