# %%
import pandas as pd

# %%
df = pd.read_csv('C:/Users/User/hh_data_project/data/processed/vacancies_clean_2025-04-17.csv')
df.head()
# Out:
#                                                title  \
# 0  IT Business Analyst/Scrum Master (Middle/Middle+)
# 1                            Data Engineer (Middle+)
# 2                  Business/Systems Analyst (Middle)
# 3  Бизнес-аналитик (в сфере автоматизации бизнес-...
# 4                      Data-инженер / DWH-специалист
#
#                                       company  \
# 0      Частная компания Global DTC Kazakhstan
# 1                      ТОО МФО Деньги говорят
# 2  ТОО Частная компания Solva Technology Ltd.
# 3                               ТОО «Izi Paq»
# 4                       АО Kolesa (АО Колеса)
#
#                                             location  \
# 0                      Алматы, проспект Достык, 210А
# 1  Алматы, Наурызбайский район, микрорайон Рахат,...
# 2  Алматы, Алмалы, Жибек Жолы, Райымбек батыра, п...
# 3                           Астана, улица Кордай, 48
# 4                Алматы, Алатау, улица Шевченко, 157
#
# ...

# %%
df.isnull().sum()
# Out:
# title                0
# company              0
# location             0
# city                 0
# salary               0
# description          0
# experience           0
# employment_type      0
# schedule             0
# working_hours        0
# work_format          0
# link                 0
# published_date       0
# skills               0
# published_date_dt    0
# about_company        0
# responsibilities     0
# requirements         0
# dtype: int64

# %%
df['skills'].value_counts().sort_values(ascending=False).head(20)
# Out:
# skills
# Не указано                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                    197
# ...
